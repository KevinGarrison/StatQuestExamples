# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt

# %%
print(pd.DataFrame({}))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
plt.boxplot([2,3,4])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f8aced2ed0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f8aced3620>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f8ace8bc20>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f8aced3bf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f8aced3ef0>],
#  'means': []}
